# %%
import pandas as pd

# %%
lst = ['snake','rat','lizard','is','reptli']
df = pd.DataFrame(lst)
print(df)
# Out:
#         0
# 0   snake
# 1     rat
# 2  lizard
# 3      is
# 4  reptli

# %%
df_zomato=pd.read_csv("/content/zomato.csv",encoding="latin-1")

# %%
df1[df1['City']=="Ghaziabad"]
# Out:
#       Restaurant ID                 Restaurant Name  Country Code       City  \
# 1116         309757  Chaudhary Ke Mashhoor Paranthe             1  Ghaziabad
# 1117         307903                   Thakur Bakers             1  Ghaziabad
# 1118         313502                       FoodByMom             1  Ghaziabad
# 1119       18409175                       Mr. Brown             1  Ghaziabad
# 1120       18456342                 Mitalis Kitchen             1  Ghaziabad
# 1121       18244229                   The Big Scoop             1  Ghaziabad
# 1122         300713                   9 Mars Lounge             1  Ghaziabad
# 1123           8623                         Barista             1  Ghaziabad
# 1124           1318                  Baskin Robbins             1  Ghaziabad
# 1125         311523                     Burger King             1  Ghaziabad
# 1126           8590                 Cafe Coffee Day             1  Ghaziabad
# ...

# %%
df
# Out:
#         0
# 0   snake
# 1     rat
# 2  lizard
# 3      is
# 4  reptli

# %%
df1 = pd.read_excel("/content/Country-Code.xlsx")

# %%
df1
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
df3=pd.marge(df,df) #marge data set
df3
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-bb3f6a5eb8c1> in <cell line: 1>()
# ----> 1 df3=pd.marge(df,df) #marge data set
#       2 df3
#
# AttributeError: module 'pandas' has no attribute 'marge'
